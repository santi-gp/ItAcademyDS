# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, RepeatedKFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score,recall_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# **Ejercicios de algoritmos de Clasificación.**

# %% [markdown]
# * Limpieza e interpretación de los datos.
# * Preprocesados.
# * Creación de modelos de clasificación (árboles de clasificación, KNN - k-Nearest neighbors, regresión logística, support vector machine, XGboost, otros modelos...).
# * Utilización de las métricas para interpretar los resultados.
# * Estudio y modificación de parámetros.

# %% [markdown]
# # Ejercicio 1
# Crea al menos dos modelos de clasificación diferentes para intentar predecir el mejor las clases del archivo adjunto.

# %% [markdown]
# # Solución

# %%
df=pd.read_csv('wineData.txt', header=None, names=['Class label','Alcohol','Malic acid',
                                                   'Ash','Alcalinity of ash',
                                                   'Magnesium', 'Total phenols',
                                                   'Flavanoids', 'Nonflavanoid phenols',
                                                   'Proanthocyanins','Color intensity',
                                                   'Hue','OD280/OD315 of diluted wines','Proline'])
df.head()
# Out:
#    Class label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0            1    14.23        1.71  2.43               15.6        127
# 1            1    13.20        1.78  2.14               11.2        100
# 2            1    13.16        2.36  2.67               18.6        101
# 3            1    14.37        1.95  2.50               16.8        113
# 4            1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185
# 3             7.80  0.86                          3.45     1480
# 4             4.32  1.04                          2.93      735

# %% [markdown]
# |Variable|Descripción|
# |--------|-----------|
# |CRIM | tasa de criminalidad per cápita por ciudad|
# |ZN | proporción de terreno residencial zonificado para lotes de más de 25.000 pies cuadrados|
# |INDUS | proporción de acres comerciales no minoristas por ciudad|
# |CHAS | variable ficticia del río Charles (1 si el tramo limita con el río; 0 en caso contrario)|
# |NOX | concentración de óxidos nítricos (partes por 10 millones)|
# |RM | número promedio de habitaciones por vivienda|
# |AGE | proporción de unidades ocupadas por propietarios construidas antes de 1940|
# |DIS | distancias ponderadas a cinco centros de empleo de Boston|
# |RAD | índice de accesibilidad a las carreteras radiales|
# |TAX | tasa del impuesto sobre bienes inmuebles de valor íntegro por 10.000 dólares|
# |PTRATIO | ratio alumno-profesor por localidad|
# |B | $1000(Bk - 0.63)^2$ donde Bk es la proporción de negros por ciudad|
# |LSTAT | porcentaje de la población de menor estatus|
# |MEDV | valor medio de las viviendas ocupadas por sus propietarios en miles de dólares|

# %% [markdown]
# ## 1.1 EDA

# %% [markdown]
# 1. Verificar si existen valores nulos.

# %%
df.isnull().sum()
# Out:
# Class label                     0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %% [markdown]
# 2. Mostrar descripción estadística de las variables.

# %%
df.describe().round(2)
# Out:
#        Class label  Alcohol  Malic acid     Ash  Alcalinity of ash  Magnesium  \
# count       178.00   178.00      178.00  178.00             178.00     178.00
# mean          1.94    13.00        2.34    2.37              19.49      99.74
# std           0.78     0.81        1.12    0.27               3.34      14.28
# min           1.00    11.03        0.74    1.36              10.60      70.00
# 25%           1.00    12.36        1.60    2.21              17.20      88.00
# 50%           2.00    13.05        1.87    2.36              19.50      98.00
# 75%           3.00    13.68        3.08    2.56              21.50     107.00
# max           3.00    14.83        5.80    3.23              30.00     162.00
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count         178.00      178.00                178.00           178.00
# mean            2.30        2.03                  0.36             1.59
# std             0.63        1.00                  0.12             0.57
# min             0.98        0.34                  0.13             0.41
# 25%             1.74        1.20                  0.27             1.25
# 50%             2.36        2.13                  0.34             1.56
# 75%             2.80        2.88                  0.44             1.95
# max             3.88        5.08                  0.66             3.58
#
#        Color intensity     Hue  OD280/OD315 of diluted wines  Proline
# count           178.00  178.00                        178.00   178.00
# mean              5.06    0.96                          2.61   746.89
# std               2.32    0.23                          0.71   314.91
# min               1.28    0.48                          1.27   278.00
# 25%               3.22    0.78                          1.94   500.50
# 50%               4.69    0.96                          2.78   673.50
# 75%               6.20    1.12                          3.17   985.00
# max              13.00    1.71                          4.00  1680.00

# %% [markdown]
# 3. Observar los tipos de datos de cada columna.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class label                   178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
#  12  OD280/OD315 of diluted wines  178 non-null    float64
#  13  Proline                       178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
f=plt.figure(figsize=(18,22))
for i , col in zip(range(1,14),df.columns):
    fplot=f.add_subplot(5,3,i)
    sns.histplot(data=df, x=col, kde=True,stat='density');

# %% [markdown]
# Aunque todas las variables son valores numéricos, se puede ver la distribución de datos y algunas también son categóricas(**Class label**).

# %% [markdown]
# 4. Correlación entre todas y cada una de las variables.

# %%
corr=df.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr, annot=True, cmap='Blues',annot_kws={'size':10},fmt='.2f',square=True);

# %% [markdown]
# Los valores van de -1 a 1, si un valor se apróxima a 1 tendrá una correlación positiva(fuerte)  y si se apróxima a -1, tendra una correlación negativa(débil). Ahora, al examinar la columna MEDV, es mucho más fácil encontrar el cuadrado más oscuro RM y el más claro LSTAT. Habrá observado que, técnicamente, el cuadrado MEDV es el más oscuro. Esto tiene que ser así porque el MEDV está perfectamente correlacionado consigo mismo. Lo mismo ocurre con cada columna a lo largo de la diagonal.

# %%
f=plt.figure(figsize=(12,5))
f1=f.add_subplot(1,2,1)
sns.regplot(x='RM',y='MEDV',data=df,scatter_kws={'alpha': 0.4})
f2=f.add_subplot(1,2,2)
sns.regplot(x='LSTAT',y='MEDV', data=df,scatter_kws={'alpha': 0.3});

# %% [markdown]
# A medida que la vivienda tiene más habitaciones (**RM**) su precio sube(gráfico de la izquierda). Por otro, si el porcentaje de la poblacón con menos estatus es alto el precio de la vivienda baja(gráfico de la derecha).

# %% [markdown]
# Visualización de la correlación de las variables con la columna de predicción **Class label**.

# %%
corr_df_medv=df.corrwith(df['Class label'])
plt.figure(figsize = (16, 4))
sns.heatmap([np.abs(corr_df_medv)],cmap='Blues',annot=True,fmt='.2%');

# %%
index_rk=corr_df_medv[:-1].abs().sort_values(ascending=False)*100
index_rk
# Out:
# Class label                     100.000000
# Flavanoids                       84.749754
# OD280/OD315 of diluted wines     78.822959
# Total phenols                    71.916334
# Hue                              61.736921
# Alcalinity of ash                51.785911
# Proanthocyanins                  49.912982
# Nonflavanoid phenols             48.910916
# Malic acid                       43.777620
# Alcohol                          32.822194
# Color intensity                  26.566757
# Magnesium                        20.917939
# Ash                               4.964322
# dtype: float64

# %% [markdown]
# ## 1.2 Construcción de modelos de clasificación

# %% [markdown]
# 1. La variable objetivo será la columna, **Class label**. Por lo tanto, la extraemos de la siguiente manera:

# %%
y=df['Class label']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Class label, Length: 178, dtype: int64

# %% [markdown]
# 2. Escogemos la columnas mejor correlacionas

# %%
#index_rk.index

# %%
#X=df[index_rk.index]
#X.head()

# %%
X=df.iloc[:,1:14]
X.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline
# 0                          3.92     1065
# 1                          3.40     1050
# 2                          3.17     1185
# 3                          3.45     1480
# 4                          2.93      735

# %% [markdown]
# 3. Normalizar los valores del conjumto **X**.

# %%
X=StandardScaler().fit_transform(X)

# %% [markdown]
# 4. Crear un funcción para evaluar nuestros modelos.

# %%
def clf_model(model,X,y):
    clf = model
    scores = cross_val_score(clf, X, y)
    print('Scores:', scores)
    print('Mean score:', scores.mean())

# %%
# X: Coonjunto que será dividido en conjunto de prueba y entrenamiento
# y: Conjunto objetivo
# model: tipo de modelo (LinnearRegression, Lasso, RandomForest, etc...)
# trainSize: tamaño de datos de entrenamiento (0.6, 0.7, 0.8)  
# testSize: tamaño de datos de prueba (0.4, 0.3, 0.2)
# trainSize + testSize, debe ser igual a 1.
def class_model(model,X,y,trainSize,testSize):
    # Crear conjuntos entrenamiento y prueba
    Xtrain, Xtest, ytrain, ytest = train_test_split(X, y,train_size=trainSize,test_size=testSize, random_state=1234)
    # Crear el modelo
    classification=model
    # Ajustar el modelo a los conjuntos de entrenamiento
    classification.fit(Xtrain,ytrain)
    # Predecir a partir de los datos de prueba
    ypred=classification.predict(Xtest)    
    return ytest, ypred

# %% [markdown]
# 5. Crear lista de modelos de clasificación

# %%
name_model=[GaussianNB(),
            SVC(kernel='linear'),
            DecisionTreeClassifier()]

# %% [markdown]
# ### 1.2.1 Gaussian naive Bayes

# %%
ytest_Gauss,ypred_Gauss=class_model(name_model[0],X,y,0.7,0.3)

# %%
plt.subplots(figsize=(10,5))
plt.hist(ytest_Gauss,label='y-objetivo')
plt.hist(ypred_Gauss,label='y-obtenido')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.2.2 Máquinas de Vector Soporte SVM

# %%
ytest_SVC, ypred_SVC = class_model(name_model[1],X,y,0.7,0.3)

# %%
plt.subplots(figsize=(10,5))
plt.hist(ytest_SVC,label='y-objetivo')
plt.hist(ypred_SVC,label='y-obtenido')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.2.3 DecisionTreeClassifier

# %%
ytest_DTC, ypred_DTC = class_model(name_model[2],X,y,0.7,0.3)

# %%
plt.subplots(figsize=(10,5))
plt.hist(ytest_DTC,label='y-objetivo')
plt.hist(ypred_DTC,label='y-obtenido')
plt.legend()
plt.show()

# %% [markdown]
# # Ejercicio 2
# Compara los modelos de clasificación utilizando la precisión (**accuracy**), una matriz de confusión y otras métricas más avanzadas.

# %% [markdown]
# # Solución

# %% [markdown]
# Podemos utilizar la función **accuracy_score** para ver la fracción de etiquetas predichas que coinciden con sus valores reales:

# %% [markdown]
# $$\text{accuracy}=\frac{\text{valores predichos}}{\text{valores reales}}$$.

# %%
def class_score(y_test,y_pred):
    print('Accuracy:',accuracy_score(y_test, y_pred))
    print('recall_score:',recall_score(y_test, y_pred,average=None))
    print('precision_score:',precision_score(y_test, y_pred,average=None))
    print('f1_Score:',f1_score(y_test, y_pred,average=None))
    precision_score

# %%
def conf_matrix(ytest,ypred):
    print('Matriz de confusión')
    CM_model = confusion_matrix(ytest,ypred)
    # Crear la visualización de la matriz de confusión
    cm_display = ConfusionMatrixDisplay(confusion_matrix = CM_model, display_labels = [1, 2,3])
    # Graficar la matriz de confusión
    cm_display.plot()
    plt.show()

# %% [markdown]
# ### 2.1 Gaussian naive Bayes

# %%
class_score(ytest_Gauss,ypred_Gauss)
# Out:
# Accuracy: 0.9259259259259259
# recall_score: [0.9375     0.86363636 1.        ]
# precision_score: [0.9375     0.95       0.88888889]
# f1_Score: [0.9375     0.9047619  0.94117647]

# %%
conf_matrix(ytest_Gauss,ypred_Gauss)
# Out:
# Matriz de confusión

# %% [markdown]
# ### 2.2 Máquinas de Vector Soporte SVM

# %%
class_score(ytest_SVC,ypred_SVC)
# Out:
# Accuracy: 0.9444444444444444
# recall_score: [0.9375     0.90909091 1.        ]
# precision_score: [1.         0.95238095 0.88888889]
# f1_Score: [0.96774194 0.93023256 0.94117647]

# %%
conf_matrix(ytest_SVC,ypred_SVC)
# Out:
# Matriz de confusión

# %% [markdown]
# ### 2.3 DecisionTreeClassifier

# %%
class_score(ytest_DTC,ypred_DTC)
# Out:
# Accuracy: 0.8888888888888888
# recall_score: [0.8125     0.86363636 1.        ]
# precision_score: [0.92857143 0.86363636 0.88888889]
# f1_Score: [0.86666667 0.86363636 0.94117647]

# %%
conf_matrix(ytest_DTC,ypred_DTC)
# Out:
# Matriz de confusión

# %% [markdown]
# $R^2$ = 1 significa que tenemos una predicción perfecta. En otras palabras, la varianza de los datos será explicada en su totalidad por el modelo. En este caso tenemos menos del 65% de la varianza explicada... No está muy bien, pero tampoco está nada mal.

# %% [markdown]
# # Ejercicio 3
# Entrénalos usando los diferentes parámetros que admiten para mejorar la predicción.

# %% [markdown]
# # Solución

# %% [markdown]
# Cambiaremos los diferentes parámetros de nuestros modelos para ver si mejoran en la predicción.

# %% [markdown]
# ### 2.1  Gaussian naive Bayes

# %%
GaussianNB().get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
y1,y2=class_model(GaussianNB(var_smoothing=1e-1),X,y,0.7,0.3)
class_score(y1,y2)
conf_matrix(y1,y2)
# Out:
# Accuracy: 0.9444444444444444
# recall_score: [0.9375     0.90909091 1.        ]
# precision_score: [1.         0.95238095 0.88888889]
# f1_Score: [0.96774194 0.93023256 0.94117647]
# Matriz de confusión

# %% [markdown]
# ### 2.2 Máquinas de Vector Soporte SVM

# %%
SVC().get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
z1,z2=class_model(SVC(kernel='poly',coef0=1,C=1),X,y,0.7,0.3)
#z1,z2=class_model(SVC(kernel='linear',C=1,random_state=1),X,y,0.7,0.3)
class_score(z1,z2)
conf_matrix(z1,z2)
# Out:
# Accuracy: 0.9814814814814815
# recall_score: [1.         0.95454545 1.        ]
# precision_score: [1.         1.         0.94117647]
# f1_Score: [1.         0.97674419 0.96969697]
# Matriz de confusión

# %% [markdown]
# ### 2.3 DecisionTreeClassifier

# %%
DecisionTreeClassifier().get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': None,
#  'splitter': 'best'}

# %%
v1,v2=class_model(DecisionTreeClassifier(criterion='entropy', min_samples_split=5),X,y,0.7,0.3)
class_score(v1,v2)
conf_matrix(v1,v2)
# Out:
# Accuracy: 0.9074074074074074
# recall_score: [0.8125     0.90909091 1.        ]
# precision_score: [1.         0.95238095 0.8       ]
# f1_Score: [0.89655172 0.93023256 0.88888889]
# Matriz de confusión

# %% [markdown]
# # Ejercicio 4
# Compare su rendimiento empleando la aproximación train/test o cross-validation.

# %% [markdown]
# # Solución

# %% [markdown]
# ### Creación de un modelo óptimo de regresión aleatoria
#
# La clase RandomForestRegressor del módulo sklearn.ensemble permite entrenar modelos random forest para problemas de regresión.

# %% [markdown]
# 1. Puntuaciones para diferentes muestras de entrenamiento

# %%
scores_train = []
for i in range(80):
    X4_train, X4_test, y4_train, y4_test = train_test_split(X, y, test_size = 0.20, random_state = i)
    rf_regressor = RandomForestRegressor(max_depth = 13, random_state = 42)
    rf_regressor.fit(X4_train, y4_train)
    scores_train.append(rf_regressor.score(X, y))

# obtener índice de la mejor puntuación 
print(f"({scores_train.index(max(scores_train))},{np.max(scores_train)})")
# Out:
# (67,0.9722252882980627)

# %% [markdown]
# 2. Puntuaciones para diferentes modelos de Randomforest

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, test_size = 0.20, random_state = 67)

scores_rfr = []
for i in range(80):
    rf_regressor = RandomForestRegressor(max_depth = 13, random_state = i)
    rf_regressor.fit(X_train4, y_train4)
    scores_rfr.append(rf_regressor.score(X, y))
    
# obtener índice de la mejor puntuación 
print(f"({scores_rfr.index(max(scores_rfr))},{np.max(scores_rfr)})")
# Out:
# (12,0.9741369800536485)

# %% [markdown]
# 3. Entrenar el modelo con la mejor puntuación de los pasos 1 y 2.

# %%
# mejor puntuación para muestras de entrenamiento i=67
# mejor puntuación para muestras de entrenamiento RandomForest i=12
X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, test_size = 0.20, random_state = 67)
rf_regressor = RandomForestRegressor(max_depth = 13, random_state = 12)
rf_regressor.fit(X_train4, y_train4)
y_pred4=rf_regressor.predict(X_test4)

df_compare4 = pd.DataFrame({"y-test":y_test4,"y-predict":y_pred4.round(2)})
df_compare4.reset_index(drop=True,inplace=True)

plt.subplots(figsize=(10,5))
x_points =list(range(len(y_test4)))
plt.plot(x_points,y_test4,label='y-objetivo')
plt.plot(x_points,y_pred4,label='y-obtenido')
plt.legend()
plt.show()

# %% [markdown]
# # Ejercicio 5
# Aplica algún proceso de ingeniería para mejorar los resultados (normalización, estandarización, muestreo...)

# %% [markdown]
# # Solución

# %% [markdown]
# 1. Creamos un nuevo conjunto **X1** eliminando las columna RM y MEDV de nuestro datset

# %%
X1=df.drop(['RM','MEDV'],axis=1) 
X1.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  65.2  4.0900    1  296.0     15.3
# 1  0.02731   0.0   7.07     0  0.469  78.9  4.9671    2  242.0     17.8
# 2  0.02729   0.0   7.07     0  0.469  61.1  4.9671    2  242.0     17.8
# 3  0.03237   0.0   2.18     0  0.458  45.8  6.0622    3  222.0     18.7
# 4  0.06905   0.0   2.18     0  0.458  54.2  6.0622    3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %% [markdown]
# 2. Predicción con el modelo de Regesión Lineal

# %%
ytest1,ypred1=reg_model(LinearRegression(),X1,y,0.8,0.2)

# %%
mse_r2(ytest1,ypred1)
# Out:
# MSE:  36.8720007898331
# R2:  0.6749273642939575

# %% [markdown]
# 3. Predicción con el modelo Lasso

# %%
ytest2,ypred2=reg_model(Lasso(alpha=0.001),X1,y,0.8,0.2)
mse_r2(ytest2,ypred2)
# Out:
# MSE:  36.88621597636264
# R2:  0.6748020397101752

# %% [markdown]
# 4. Predicción con el modelo de Ridge

# %%
ytest3,ypred3=reg_model(Ridge(alpha=0.001),X1,y,0.8,0.2)
mse_r2(ytest3,ypred3)
# Out:
# MSE:  36.872629444691725
# R2:  0.6749218219179687

# %% [markdown]
# ### Particiones repetidas de entrenamiento-prueba
