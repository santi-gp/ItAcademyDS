# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, RepeatedKFold, cross_val_score, cross_val_predict, KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score,recall_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# **Ejercicios de algoritmos de Clasificación.**

# %% [markdown]
# * Limpieza e interpretación de los datos.
# * Preprocesados.
# * Creación de modelos de clasificación (árboles de clasificación, KNN - k-Nearest neighbors, regresión logística, support vector machine, XGboost, otros modelos...).
# * Utilización de las métricas para interpretar los resultados.
# * Estudio y modificación de parámetros.

# %% [markdown]
# # Ejercicio 1
# Crea al menos dos modelos de clasificación diferentes para intentar predecir el mejor las clases del archivo adjunto.

# %% [markdown]
# # Solución

# %%
df=pd.read_csv('wineData.txt', header=None, names=['Class label','Alcohol','Malic acid',
                                                   'Ash','Alcalinity of ash',
                                                   'Magnesium', 'Total phenols',
                                                   'Flavanoids', 'Nonflavanoid phenols',
                                                   'Proanthocyanins','Color intensity',
                                                   'Hue','OD280/OD315 of diluted wines','Proline'])
df.head()
# Out:
#    Class label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0            1    14.23        1.71  2.43               15.6        127
# 1            1    13.20        1.78  2.14               11.2        100
# 2            1    13.16        2.36  2.67               18.6        101
# 3            1    14.37        1.95  2.50               16.8        113
# 4            1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185
# 3             7.80  0.86                          3.45     1480
# 4             4.32  1.04                          2.93      735

# %% [markdown]
# |Variable|Descripción|
# |--------|-----------|
# |Class label | Etiqueta de clase|
# |Alcohol | Alcohol|
# |Malic acid | Ácido málico|
# |Ash | Cenizas|
# |Alcalinity of ash | Alcalinidad de las cenizas|
# |Magnesium | Magnesio|
# |Total phenols | Fenoles totales|
# |Flavanoids | Flavonoides|
# |Nonflavanoid phenols | Fenoles no flavonoides|
# |Proanthocyanins | Proantocianinas|
# |Color intensity | Intensidad de color|
# |Hue | Tonalidad|
# |OD280/OD315 of diluted wines | DO280/OD315 de vinos diluidos|
# |Proline | Prolina|

# %% [markdown]
# ## 1.1 EDA

# %% [markdown]
# 1. Verificar si existen valores nulos.

# %%
df.isnull().sum()
# Out:
# Class label                     0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %% [markdown]
# 2. Mostrar descripción estadística de las variables.

# %%
df.describe().round(2)
# Out:
#        Class label  Alcohol  Malic acid     Ash  Alcalinity of ash  Magnesium  \
# count       178.00   178.00      178.00  178.00             178.00     178.00
# mean          1.94    13.00        2.34    2.37              19.49      99.74
# std           0.78     0.81        1.12    0.27               3.34      14.28
# min           1.00    11.03        0.74    1.36              10.60      70.00
# 25%           1.00    12.36        1.60    2.21              17.20      88.00
# 50%           2.00    13.05        1.87    2.36              19.50      98.00
# 75%           3.00    13.68        3.08    2.56              21.50     107.00
# max           3.00    14.83        5.80    3.23              30.00     162.00
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count         178.00      178.00                178.00           178.00
# mean            2.30        2.03                  0.36             1.59
# std             0.63        1.00                  0.12             0.57
# min             0.98        0.34                  0.13             0.41
# 25%             1.74        1.20                  0.27             1.25
# 50%             2.36        2.13                  0.34             1.56
# 75%             2.80        2.88                  0.44             1.95
# max             3.88        5.08                  0.66             3.58
#
#        Color intensity     Hue  OD280/OD315 of diluted wines  Proline
# count           178.00  178.00                        178.00   178.00
# mean              5.06    0.96                          2.61   746.89
# std               2.32    0.23                          0.71   314.91
# min               1.28    0.48                          1.27   278.00
# 25%               3.22    0.78                          1.94   500.50
# 50%               4.69    0.96                          2.78   673.50
# 75%               6.20    1.12                          3.17   985.00
# max              13.00    1.71                          4.00  1680.00

# %% [markdown]
# 3. Observar los tipos de datos de cada columna.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class label                   178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
#  12  OD280/OD315 of diluted wines  178 non-null    float64
#  13  Proline                       178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
f=plt.figure(figsize=(18,22))
for i , col in zip(range(1,14),df.columns):
    fplot=f.add_subplot(5,3,i)
    sns.histplot(data=df, x=col, kde=True,stat='density');

# %% [markdown]
# A excepción de **Class label**, las demás variables son numéricas , se puede ver en la distribución de datos.

# %% [markdown]
# 4. Correlación entre todas y cada una de las variables.

# %%
corr=df.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr, annot=True, cmap='Blues',annot_kws={'size':10},fmt='.2f',square=True);

# %% [markdown]
# Los valores van de -1 a 1, si un valor se apróxima a 1 tendrá una correlación positiva(fuerte)  y si se apróxima a -1, tendra una correlación negativa(débil).
#
# Algunas características tienen una correlación lineal bastante elevada:
#
# * flavanoids & total phenols = 0.86
# * flavanoids & od280/od315_of_diluted_wines = 0.79

# %%
f=plt.figure(figsize=(12,5))
f1=f.add_subplot(1,2,1)
sns.regplot(x='Total phenols',y='Class label',data=df,scatter_kws={'alpha': 0.4})
f2=f.add_subplot(1,2,2)
sns.regplot(x='Proline',y='Class label', data=df,scatter_kws={'alpha': 0.3});

# %% [markdown]
# A medida que la vivienda tiene más habitaciones (**RM**) su precio sube(gráfico de la izquierda). Por otro, si el porcentaje de la poblacón con menos estatus es alto el precio de la vivienda baja(gráfico de la derecha).

# %% [markdown]
# ## 1.2 Construcción de modelos de clasificación

# %% [markdown]
# 1. La variable objetivo será la columna **Class label**. Por lo tanto, la extraemos de la siguiente manera:

# %%
y=df['Class label']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Class label, Length: 178, dtype: int64

# %%
X=df.iloc[:,1:14]
X.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline
# 0                          3.92     1065
# 1                          3.40     1050
# 2                          3.17     1185
# 3                          3.45     1480
# 4                          2.93      735

# %% [markdown]
# 2. Crear un funcción para evaluar nuestros modelos.

# %%
# X: Coonjunto que será dividido en conjunto de prueba y entrenamiento
# y: Conjunto objetivo
# model: tipo de modelo (LinnearRegression, Lasso, RandomForest, etc...)
# trainSize: tamaño de datos de entrenamiento (0.6, 0.7, 0.8)  
# testSize: tamaño de datos de prueba (0.4, 0.3, 0.2)
# trainSize + testSize, debe ser igual a 1.
def class_model(model,X,y,trainSize,testSize):
    # Crear conjuntos entrenamiento y prueba
    Xtrain, Xtest, ytrain, ytest = train_test_split(X, y,train_size=trainSize,test_size=testSize, random_state=37)
    # Crear el modelo
    classification=model
    # Ajustar el modelo a los conjuntos de entrenamiento
    classification.fit(Xtrain,ytrain)
    # Predecir a partir de los datos de prueba
    ypred=classification.predict(Xtest)    
    return ytest, ypred

# %% [markdown]
# 3. Crear lista de modelos de clasificación

# %%
name_model=[GaussianNB(),
            SVC(kernel='linear'),
            DecisionTreeClassifier()]

# %% [markdown]
# ### 1.2.1 Gaussian naive Bayes

# %%
ytest_Gauss,ypred_Gauss=class_model(name_model[0],X,y,0.8,0.2)

# %%
plt.subplots(figsize=(10,5))
plt.hist(ytest_Gauss,label='y-objetivo')
plt.hist(ypred_Gauss,label='y-obtenido')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.2.2 Máquinas de Vector Soporte SVM

# %%
ytest_SVC, ypred_SVC = class_model(name_model[1],X,y,0.8,0.2)

# %%
plt.subplots(figsize=(10,5))
plt.hist(ytest_SVC,label='y-objetivo')
plt.hist(ypred_SVC,label='y-obtenido')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.2.3 DecisionTreeClassifier

# %%
ytest_DTC, ypred_DTC = class_model(name_model[2],X,y,0.8,0.2)

# %%
plt.subplots(figsize=(10,5))
plt.hist(ytest_DTC,label='y-objetivo')
plt.hist(ypred_DTC,label='y-obtenido')
plt.legend()
plt.show()

# %% [markdown]
# # Ejercicio 2
# Compara los modelos de clasificación utilizando la precisión (**accuracy**), una matriz de confusión y otras métricas más avanzadas.

# %% [markdown]
# # Solución

# %% [markdown]
# Podemos utilizar la función **accuracy_score** para ver la fracción de etiquetas predichas que coinciden con sus valores reales:

# %% [markdown]
# $$\text{accuracy}=\frac{\text{valores predichos}}{\text{valores reales}}$$.

# %% [markdown]
# 1. Crear función de diferentes medidas de puntuación

# %%
def class_score(y_test,y_pred):
    print('Accuracy:',accuracy_score(y_test, y_pred))
    print('recall_score:',recall_score(y_test, y_pred,average=None))
    print('precision_score:',precision_score(y_test, y_pred,average=None))
    print('f1_Score:',f1_score(y_test, y_pred,average=None))
    precision_score

# %% [markdown]
# 2. Crear funcón que grafique la matriz de confusión

# %%
def conf_matrix(ytest,ypred):
    print('Matriz de confusión')
    CM_model = confusion_matrix(ytest,ypred)
    # Crear la visualización de la matriz de confusión
    cm_display = ConfusionMatrixDisplay(confusion_matrix = CM_model, display_labels = [1, 2,3])
    # Graficar la matriz de confusión
    cm_display.plot()
    plt.show()

# %% [markdown]
# 3. Evaluar modelos con las dos funciones creadas en los pasos 1 y 2.

# %% [markdown]
# ### 2.1 Gaussian naive Bayes

# %%
class_score(ytest_Gauss,ypred_Gauss)
# Out:
# Accuracy: 0.9722222222222222
# recall_score: [1.         0.92857143 1.        ]
# precision_score: [0.92307692 1.         1.        ]
# f1_Score: [0.96       0.96296296 1.        ]

# %%
conf_matrix(ytest_Gauss,ypred_Gauss)
# Out:
# Matriz de confusión

# %% [markdown]
# ### 2.2 Máquinas de Vector Soporte SVM

# %%
class_score(ytest_SVC,ypred_SVC)
# Out:
# Accuracy: 0.8611111111111112
# recall_score: [1.         0.71428571 0.9       ]
# precision_score: [0.8        0.90909091 0.9       ]
# f1_Score: [0.88888889 0.8        0.9       ]

# %%
conf_matrix(ytest_SVC,ypred_SVC)
# Out:
# Matriz de confusión

# %% [markdown]
# ### 2.3 DecisionTreeClassifier

# %%
class_score(ytest_DTC,ypred_DTC)
# Out:
# Accuracy: 0.8055555555555556
# recall_score: [0.83333333 0.71428571 0.9       ]
# precision_score: [0.76923077 0.83333333 0.81818182]
# f1_Score: [0.8        0.76923077 0.85714286]

# %%
conf_matrix(ytest_DTC,ypred_DTC)
# Out:
# Matriz de confusión

# %% [markdown]
# # Ejercicio 3
# Entrénalos usando los diferentes parámetros que admiten para mejorar la predicción.

# %% [markdown]
# # Solución

# %% [markdown]
# Cambiaremos los diferentes parámetros de nuestros modelos para ver si mejoran en la predicción. Para este propósito utillizaremos el método **get_paramas()** para obtener información de los diferentes parámetros que admiten nuestros modelos. Por último, iremos modificando estos parámetros para que nuestros mdelos puedan mejorar su predicción.

# %% [markdown]
# ### 2.1  Gaussian naive Bayes

# %%
GaussianNB().get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
y1,y2=class_model(GaussianNB(var_smoothing=1e-7),X,y,0.8,0.2)
class_score(y1,y2)
conf_matrix(y1,y2)
# Out:
# Accuracy: 0.9722222222222222
# recall_score: [1.         0.92857143 1.        ]
# precision_score: [0.92307692 1.         1.        ]
# f1_Score: [0.96       0.96296296 1.        ]
# Matriz de confusión

# %% [markdown]
# ### 2.2 Máquinas de Vector Soporte SVM

# %%
SVC().get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
z1,z2=class_model(SVC(kernel='linear',C=0.1),X,y,0.8,0.2)
#z1,z2=class_model(SVC(kernel='linear',C=1,random_state=1),X,y,0.7,0.3)
class_score(z1,z2)
conf_matrix(z1,z2)
# Out:
# Accuracy: 0.8888888888888888
# recall_score: [1.         0.78571429 0.9       ]
# precision_score: [0.8        0.91666667 1.        ]
# f1_Score: [0.88888889 0.84615385 0.94736842]
# Matriz de confusión

# %% [markdown]
# ### 2.3 DecisionTreeClassifier

# %%
DecisionTreeClassifier().get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': None,
#  'splitter': 'best'}

# %%
v1,v2=class_model(DecisionTreeClassifier(criterion='entropy', min_samples_split=5),X,y,0.8,0.2)
class_score(v1,v2)
conf_matrix(v1,v2)
# Out:
# Accuracy: 0.9166666666666666
# recall_score: [1.         0.78571429 1.        ]
# precision_score: [0.8 1.  1. ]
# f1_Score: [0.88888889 0.88       1.        ]
# Matriz de confusión

# %% [markdown]
# # Ejercicio 4
# Compare su rendimiento empleando la aproximación train/test o cross-validation.

# %% [markdown]
# # Solución

# %% [markdown]
# ###  Valiación cruzada (Cross-Validation)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9444444444444444

# %%
conf_matrix(y_test,y_pred)
# Out:
# Matriz de confusión

# %%
k_values = [i for i in range (1,30)]
scores = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    score = cross_val_score(knn, X, y, cv=5)
    scores.append(np.mean(score))

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x = k_values, y = scores, marker = 'o')
plt.xlabel("Valores k")
plt.ylabel("Puntuación de precisión")
plt.show()

# %%
best_index = np.argmax(scores)
best_k = k_values[best_index]

KNN = KNeighborsClassifier(n_neighbors=best_k)
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred2 = KNN.predict(X_test)

accuracy = accuracy_score(y_test, y_pred2)


print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9722222222222222

# %%
conf_matrix(y_test,y_pred2)
# Out:
# Matriz de confusión

# %% [markdown]
# ### Particiones repetidas de entrenamiento-prueba

# %%
def tts_fit_score(model , metric, test_size=.2):
    tts = train_test_split(X,y,test_size=test_size)
    (train_ftrs, test_ftrs, train_tgt,test_tgt) = tts
    fit = model_fit.fit(train_ftrs, train_tgt)
    preds = fit.predict(test_ftrs)
    score = metric(test_tgt, preds)
    return score

# %%
model_fit = GaussianNB()
scores = [tts_fit_score(model_fit, accuracy_score) for i in range(30)]
plt.figure(figsize=(10,6))
plt.plot(scores,marker = 'o')
plt.show()

# %% [markdown]
# # Ejercicio 5
# Aplica algún proceso de ingeniería para mejorar los resultados (normalización, estandarización, muestreo...)

# %% [markdown]
# # Solución

# %% [markdown]
# 1. Visualización de la correlación de las variables con la columna de predicción **Class label**.

# %%
corr_df_class=df.corrwith(df['Class label'])
plt.figure(figsize = (16, 4))
sns.heatmap([np.abs(corr_df_class)],cmap='Purples',annot=True,fmt='.2%');

# %%
index_rk=corr_df_class[1:].abs().sort_values(ascending=False)*100
index_rk
# Out:
# Flavanoids                      84.749754
# OD280/OD315 of diluted wines    78.822959
# Total phenols                   71.916334
# Proline                         63.371678
# Hue                             61.736921
# Alcalinity of ash               51.785911
# Proanthocyanins                 49.912982
# Nonflavanoid phenols            48.910916
# Malic acid                      43.777620
# Alcohol                         32.822194
# Color intensity                 26.566757
# Magnesium                       20.917939
# Ash                              4.964322
# dtype: float64

# %% [markdown]
# 2. Escogemos la columnas mejor correlacionas

# %%
index_rk.index
# Out:
# Index(['Flavanoids', 'OD280/OD315 of diluted wines', 'Total phenols',
#        'Proline', 'Hue', 'Alcalinity of ash', 'Proanthocyanins',
#        'Nonflavanoid phenols', 'Malic acid', 'Alcohol', 'Color intensity',
#        'Magnesium', 'Ash'],
#       dtype='object')

# %% [markdown]
# Vamos eliminar la  columna **Ash** pues representa el 5% de los datos

# %%
X=df[index_rk.index[:-1]]
X.head()
# Out:
#    Flavanoids  OD280/OD315 of diluted wines  Total phenols  Proline   Hue  \
# 0        3.06                          3.92           2.80     1065  1.04
# 1        2.76                          3.40           2.65     1050  1.05
# 2        3.24                          3.17           2.80     1185  1.03
# 3        3.49                          3.45           3.85     1480  0.86
# 4        2.69                          2.93           2.80      735  1.04
#
#    Alcalinity of ash  Proanthocyanins  Nonflavanoid phenols  Malic acid  \
# 0               15.6             2.29                  0.28        1.71
# 1               11.2             1.28                  0.26        1.78
# 2               18.6             2.81                  0.30        2.36
# 3               16.8             2.18                  0.24        1.95
# 4               21.0             1.82                  0.39        2.59
#
#    Alcohol  Color intensity  Magnesium
# 0    14.23             5.64        127
# 1    13.20             4.38        100
# 2    13.16             5.68        101
# 3    14.37             7.80        113
# 4    13.24             4.32        118

# %% [markdown]
# 1. Normalizar los valores del conjumto **X**.

# %%
X=StandardScaler().fit_transform(X)

# %%
logreg=LogisticRegression(multi_class='multinomial')
predicted = cross_val_predict(logreg, X, y, cv=10)
print(accuracy_score(y, predicted))
# Out:
# 0.9719101123595506

# %%
k= 5
kf = KFold(n_splits=k, random_state=None)
model = LogisticRegression(multi_class='multinomial')
 
result = cross_val_score(model , X, y, cv = kf)
 
print("Puntuación media: {}".format(result.mean()))
# Out:
# Puntuación media: 0.9330158730158729
